# %% [markdown]
# # Hackaton Desafio Budokai
#
# ## Equipe 11

# %% [markdown]
# ### notebook_v3: A ideia principal nesta versão é criar um pipeline para testar vários modelos e descobrir suas perfomances.

# %% [markdown]
# ## Bibliotecas:

# %%
#importanto bibliotecas

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model, preprocessing

#import statsmodels.api as sm
#from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import mean_absolute_error

from sklearn.preprocessing import StandardScaler
from datetime import datetime

from sklearn.linear_model import Lasso, LassoCV
from sklearn.impute import SimpleImputer

from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Lendo csv e removendo algumas colunas redundantes:

# %%
Y_train=pd.read_csv('shared/bases_budokai_ufpr/produtividade_soja_modelagem.csv')
df=pd.read_csv('shared/bases_budokai_ufpr/agroclimatology_budokai.csv')

# %%
Y_train.head()
# Out:
#   nivel  codigo_ibge                  name    2004    2005    2006    2007  \
# 0    MU      4100103                Abatiá  2600.0  1750.0  2100.0  2600.0
# 1    MU      4100459    Altamira do Paraná  3100.0  2460.0  2950.0  2950.0
# 2    MU      4100608           Alto Paraná  1487.0  1365.0  1734.0  2727.0
# 3    MU      4100707          Alto Piquiri  2300.0  2300.0  2700.0  3193.0
# 4    MU      4100509               Altônia  1050.0  1800.0  1255.0  2355.0
#
#      2008    2009    2010    2011    2012    2013    2014    2015    2016  \
# 0  2600.0  2080.0  2590.0  3350.0  2320.0  3100.0  1460.0  2640.0  2760.0
# 1  2749.0  2749.0  3250.0  3200.0  2197.0  3223.0  3471.0  3099.0  2871.0
# 2  2400.0  1620.0  2899.0  2899.0  1737.0  2880.0  2000.0  1800.0  2221.0
# 3  2701.0  2097.0  3130.0  3310.0  2000.0  3000.0  3192.0  3488.0  2589.0
# 4  2600.0  1300.0  3000.0  2773.0   815.0  2137.0  1800.0  2455.0  2780.0
#
#      2017
# 0  3480.0
# 1  3818.0
# 2  2980.0
# 3  3700.0
# 4  2900.0

# %%
Y_train['nivel'].unique()
# Out:
# array(['MU'], dtype=object)

# %%
#Y_codigo=Y_train['codigo_ibge']

Y_train=Y_train.drop(columns=['nivel', 'name'])

# %%
Y_train.head()
# Out:
#    codigo_ibge    2004    2005    2006    2007    2008    2009    2010  \
# 0      4100103  2600.0  1750.0  2100.0  2600.0  2600.0  2080.0  2590.0
# 1      4100459  3100.0  2460.0  2950.0  2950.0  2749.0  2749.0  3250.0
# 2      4100608  1487.0  1365.0  1734.0  2727.0  2400.0  1620.0  2899.0
# 3      4100707  2300.0  2300.0  2700.0  3193.0  2701.0  2097.0  3130.0
# 4      4100509  1050.0  1800.0  1255.0  2355.0  2600.0  1300.0  3000.0
#
#      2011    2012    2013    2014    2015    2016    2017
# 0  3350.0  2320.0  3100.0  1460.0  2640.0  2760.0  3480.0
# 1  3200.0  2197.0  3223.0  3471.0  3099.0  2871.0  3818.0
# 2  2899.0  1737.0  2880.0  2000.0  1800.0  2221.0  2980.0
# 3  3310.0  2000.0  3000.0  3192.0  3488.0  2589.0  3700.0
# 4  2773.0   815.0  2137.0  1800.0  2455.0  2780.0  2900.0

# %% [markdown]
# ### De acordo com as respostas esperadas temos:

# %%
codigo_saida=[4102000,4104303,4104428,4104808,4104907,4109401,4113205,4113700,4113734,4114005,4114401,4117701,4117909,4119608,4119905,4127007,4127403,4127502,4127700,4128005
]

# %%
dataset=pd.DataFrame(columns=df.keys())
#dataset.loc[dataset['codigo_ibge']==codigo_saida[j]]

for k in codigo_saida:
    dataset=pd.concat([df.loc[df['codigo_ibge']==k],dataset])

dataset=dataset.reset_index(drop=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131500 entries, 0 to 131499
# Data columns (total 38 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   data                 131500 non-null  object
#  1   codigo_ibge          131500 non-null  object
#  2   latitude             131500 non-null  float64
#  3   longitude            131500 non-null  float64
#  4   T2M_RANGE            131500 non-null  float64
#  5   TS                   131500 non-null  float64
#  6   T2MDEW               131500 non-null  float64
#  7   T2MWET               131500 non-null  float64
#  8   T2M_MAX              131500 non-null  float64
#  9   T2M_MIN              131500 non-null  float64
#  10  T2M                  131500 non-null  float64
#  11  QV2M                 131500 non-null  float64
#  12  RH2M                 131500 non-null  float64
#  13  PRECTOTCORR          131500 non-null  float64
#  14  PS                   131500 non-null  float64
#  15  WS2M                 131500 non-null  float64
#  16  WS2M_MAX             131500 non-null  float64
#  17  WS2M_MIN             131500 non-null  float64
#  18  WS2M_RANGE           131500 non-null  float64
#  19  WS10M                131500 non-null  float64
#  20  WS10M_MAX            131500 non-null  float64
#  21  WS10M_MIN            131500 non-null  float64
#  22  WS10M_RANGE          131500 non-null  float64
#  23  WS50M                131500 non-null  float64
#  24  WS50M_MAX            131500 non-null  float64
#  25  WS50M_MIN            131500 non-null  float64
#  26  WS50M_RANGE          131500 non-null  float64
#  27  GWETTOP              131500 non-null  float64
#  28  GWETROOT             131500 non-null  float64
#  29  GWETPROF             131500 non-null  float64
#  30  ALLSKY_SFC_SW_DWN    131500 non-null  float64
#  31  CLRSKY_SFC_SW_DWN    131500 non-null  float64
#  32  TOA_SW_DWN           131500 non-null  float64
#  33  ALLSKY_SFC_PAR_TOT   131500 non-null  float64
#  34  CLRSKY_SFC_PAR_TOT   131500 non-null  float64
#  35  ALLSKY_SFC_UVA       131500 non-null  float64
#  36  ALLSKY_SFC_UVB       131500 non-null  float64
#  37  ALLSKY_SFC_UV_INDEX  131500 non-null  float64
# dtypes: float64(36), object(2)
# memory usage: 38.1+ MB

# %% [markdown]
# #### Transformando o codigo em inteiro novamente.

# %%
dataset['codigo_ibge']=list(map(int,dataset['codigo_ibge']))

#df.loc[df['codigo_ibge']==codigo_saida[0]]

# %% [markdown]
# ### Vamos começar transformando os dados de data em 'datetime' para melhor agrupar em semanas, meses ou anos.

# %%
def t_data_day(data):
    data=str(data)
    data=datetime.strptime(data,"%Y%m%d")
    return data.day

def t_data_month(data):
    data=str(data)
    data=datetime.strptime(data,"%Y%m%d")
    return data.month

def t_data_year(data):
    data=str(data)
    data=datetime.strptime(data,"%Y%m%d")
    return data.year
    #return data.day, data.month, data.year

# %%
dataset['day']=list(map(t_data_day, dataset['data']))
dataset['month']=list(map(t_data_month, dataset['data']))
dataset['year']=list(map(t_data_year, dataset['data']))

# %%
dataset.head()
# Out:
#        data  codigo_ibge  latitude  longitude  T2M_RANGE     TS  T2MDEW  \
# 0  20030101      4128005  -24.5393   -52.9865       7.99  26.27   23.23
# 1  20030102      4128005  -24.5393   -52.9865       6.47  25.70   23.36
# 2  20030103      4128005  -24.5393   -52.9865       6.27  24.75   22.78
# 3  20030104      4128005  -24.5393   -52.9865       6.38  24.50   22.21
# 4  20030105      4128005  -24.5393   -52.9865       8.43  25.62   22.50
#
#    T2MWET  T2M_MAX  T2M_MIN  ...  CLRSKY_SFC_SW_DWN  TOA_SW_DWN  \
# 0   24.83    30.21    22.21  ...              30.59       42.56
# 1   24.59    29.33    22.86  ...              29.79       42.55
# 2   23.78    28.03    21.76  ...              29.66       42.53
# 3   23.29    27.82    21.44  ...              28.35       42.51
# 4   23.95    29.68    21.24  ...              29.04       42.49
#
#    ALLSKY_SFC_PAR_TOT  CLRSKY_SFC_PAR_TOT  ALLSKY_SFC_UVA  ALLSKY_SFC_UVB  \
# 0              133.74              165.12           18.27            0.56
# 1              111.66              161.13           15.38            0.48
# 2               89.88              161.48           12.85            0.41
# 3               87.03              153.10           12.10            0.40
# 4               52.05              156.25            7.56            0.24
#
#    ALLSKY_SFC_UV_INDEX  day  month  year
# 0                 2.95    1      1  2003
# 1                 2.55    2      1  2003
# 2                 2.12    3      1  2003
# 3                 2.05    4      1  2003
# 4                 1.24    5      1  2003
#
# [5 rows x 41 columns]

# %% [markdown]
# #### Uma feature importante é o valor da produção do ano passado, podemos tentar prever a produção de 2013 e criar uma feature depois.

# %%
dataset=dataset.drop(dataset.loc[dataset['year']==2003].index).reset_index(drop=True)

# %% [markdown]
# ### Podemo implementar um sistema para previsões baseado na média dos valores mensais.

# %%
dataset=dataset.drop(columns=['data','latitude','longitude','day'])

# %% [markdown]
# #### Para cada codigo postal iremos fazer um subgrupo para cada ano e agrupar os meses pela média.
#
# #### Depois concatenamos e criamos o novo dataset.

# %%
codigos=dataset['codigo_ibge'].unique()
anos=dataset['year'].unique()

datanew=pd.DataFrame(columns=dataset.keys())

for i in codigos:
    for j in anos:
        aux = dataset.loc[dataset['codigo_ibge']==i].loc[dataset['year']==j].groupby(by='month').agg('mean').reset_index()
        datanew=pd.concat([datanew,aux])
    
datanew=datanew.reset_index(drop=True)

# %%
datanew.head()
# Out:
#   codigo_ibge  T2M_RANGE         TS     T2MDEW     T2MWET    T2M_MAX  \
# 0     4128005  12.313226  27.513548  19.130968  22.804839  32.921290
# 1     4128005  12.955517  27.584483  18.363448  22.427931  33.331379
# 2     4128005  13.622258  26.335806  17.173871  21.365806  32.728065
# 3     4128005  10.766667  24.591000  19.021667  21.618333  30.242667
# 4     4128005   9.320645  17.494516  14.863548  16.181613  22.614839
#
#      T2M_MIN        T2M       QV2M       RH2M  ...  ALLSKY_SFC_SW_DWN  \
# 0  20.608387  26.477097  14.547742  67.569032  ...          23.842258
# 1  20.375172  26.492414  13.849310  64.810690  ...          23.348966
# 2  19.107419  25.557097  12.963548  64.225806  ...          21.451613
# 3  19.473667  24.218667  14.357000  75.240000  ...          16.357333
# 4  13.293871  17.502581  11.179355  85.648387  ...          11.521935
#
#    CLRSKY_SFC_SW_DWN  TOA_SW_DWN  ALLSKY_SFC_PAR_TOT  CLRSKY_SFC_PAR_TOT  \
# 0          29.756452   42.040000          129.152258          157.907419
# 1          28.156207   39.736207          126.227931          149.815517
# 2          25.462581   35.433226          113.812581          134.426774
# 3          20.808667   29.943000           88.034000          111.137667
# 4          17.273548   25.104194           60.481613           90.170645
#
#    ALLSKY_SFC_UVA  ALLSKY_SFC_UVB  ALLSKY_SFC_UV_INDEX  month  year
# 0       17.224516        0.526452           -29.573548      1  2004
# 1       16.812759        0.507586             2.653793      2  2004
# 2       15.015484        0.436452           -30.048387      3  2004
# 3       11.629667        0.323000           -31.676667      4  2004
# 4        7.898387        0.194516           -31.256452      5  2004
#
# [5 rows x 37 columns]

# %% [markdown]
# ### Precisamos colocar os dados dos meses em uma unica linha para alimentar a entrada do modelo.

# %% [markdown]
# #### Criando a lista de indices:

# %%
col=list(datanew.keys())
col.remove('year')
col.remove('codigo_ibge')
#removendo os dados que não serão escalados

# %%
lista_indices=[]

lista_indices.append('codigo_ibge')

for i in range(12):

    
    for j in col:
        
        aux=j+'_'+str(i+1)
        lista_indices.append(aux)
        
lista_indices.append('month')
lista_indices.append('year')

# %%
lista_indices
# Out:
# ['codigo_ibge',
#  'T2M_RANGE_1',
#  'TS_1',
#  'T2MDEW_1',
#  'T2MWET_1',
#  'T2M_MAX_1',
#  'T2M_MIN_1',
#  'T2M_1',
#  'QV2M_1',
#  'RH2M_1',
#  'PRECTOTCORR_1',
#  'PS_1',
#  'WS2M_1',
#  'WS2M_MAX_1',
#  'WS2M_MIN_1',
#  'WS2M_RANGE_1',
#  'WS10M_1',
#  'WS10M_MAX_1',
#  'WS10M_MIN_1',
#  'WS10M_RANGE_1',
#  'WS50M_1',
#  'WS50M_MAX_1',
#  'WS50M_MIN_1',
#  'WS50M_RANGE_1',
#  'GWETTOP_1',
#  'GWETROOT_1',
#  'GWETPROF_1',
#  'ALLSKY_SFC_SW_DWN_1',
#  'CLRSKY_SFC_SW_DWN_1',
#  'TOA_SW_DWN_1',
#  'ALLSKY_SFC_PAR_TOT_1',
#  'CLRSKY_SFC_PAR_TOT_1',
#  'ALLSKY_SFC_UVA_1',
#  'ALLSKY_SFC_UVB_1',
#  'ALLSKY_SFC_UV_INDEX_1',
#  'month_1',
#  'T2M_RANGE_2',
#  'TS_2',
#  'T2MDEW_2',
#  'T2MWET_2',
#  'T2M_MAX_2',
#  'T2M_MIN_2',
#  'T2M_2',
#  'QV2M_2',
#  'RH2M_2',
#  'PRECTOTCORR_2',
#  'PS_2',
#  'WS2M_2',
#  'WS2M_MAX_2',
#  'WS2M_MIN_2',
#  'WS2M_RANGE_2',
#  'WS10M_2',
#  'WS10M_MAX_2',
#  'WS10M_MIN_2',
#  'WS10M_RANGE_2',
#  'WS50M_2',
#  'WS50M_MAX_2',
#  'WS50M_MIN_2',
#  'WS50M_RANGE_2',
#  'GWETTOP_2',
#  'GWETROOT_2',
#  'GWETPROF_2',
#  'ALLSKY_SFC_SW_DWN_2',
#  'CLRSKY_SFC_SW_DWN_2',
#  'TOA_SW_DWN_2',
#  'ALLSKY_SFC_PAR_TOT_2',
#  'CLRSKY_SFC_PAR_TOT_2',
#  'ALLSKY_SFC_UVA_2',
#  'ALLSKY_SFC_UVB_2',
#  'ALLSKY_SFC_UV_INDEX_2',
#  'month_2',
#  'T2M_RANGE_3',
#  'TS_3',
#  'T2MDEW_3',
#  'T2MWET_3',
#  'T2M_MAX_3',
#  'T2M_MIN_3',
#  'T2M_3',
#  'QV2M_3',
#  'RH2M_3',
#  'PRECTOTCORR_3',
#  'PS_3',
#  'WS2M_3',
#  'WS2M_MAX_3',
#  'WS2M_MIN_3',
#  'WS2M_RANGE_3',
#  'WS10M_3',
#  'WS10M_MAX_3',
#  'WS10M_MIN_3',
#  'WS10M_RANGE_3',
#  'WS50M_3',
#  'WS50M_MAX_3',
#  'WS50M_MIN_3',
#  'WS50M_RANGE_3',
#  'GWETTOP_3',
#  'GWETROOT_3',
#  'GWETPROF_3',
#  'ALLSKY_SFC_SW_DWN_3',
#  'CLRSKY_SFC_SW_DWN_3',
#  'TOA_SW_DWN_3',
#  'ALLSKY_SFC_PAR_TOT_3',
#  'CLRSKY_SFC_PAR_TOT_3',
#  'ALLSKY_SFC_UVA_3',
#  'ALLSKY_SFC_UVB_3',
#  'ALLSKY_SFC_UV_INDEX_3',
#  'month_3',
#  'T2M_RANGE_4',
#  'TS_4',
#  'T2MDEW_4',
#  'T2MWET_4',
#  'T2M_MAX_4',
#  'T2M_MIN_4',
#  'T2M_4',
#  'QV2M_4',
#  'RH2M_4',
#  'PRECTOTCORR_4',
#  'PS_4',
#  'WS2M_4',
#  'WS2M_MAX_4',
#  'WS2M_MIN_4',
#  'WS2M_RANGE_4',
#  'WS10M_4',
#  'WS10M_MAX_4',
#  'WS10M_MIN_4',
#  'WS10M_RANGE_4',
#  'WS50M_4',
#  'WS50M_MAX_4',
#  'WS50M_MIN_4',
#  'WS50M_RANGE_4',
#  'GWETTOP_4',
#  'GWETROOT_4',
#  'GWETPROF_4',
#  'ALLSKY_SFC_SW_DWN_4',
#  'CLRSKY_SFC_SW_DWN_4',
#  'TOA_SW_DWN_4',
#  'ALLSKY_SFC_PAR_TOT_4',
#  'CLRSKY_SFC_PAR_TOT_4',
#  'ALLSKY_SFC_UVA_4',
#  'ALLSKY_SFC_UVB_4',
#  'ALLSKY_SFC_UV_INDEX_4',
#  'month_4',
#  'T2M_RANGE_5',
#  'TS_5',
#  'T2MDEW_5',
#  'T2MWET_5',
#  'T2M_MAX_5',
#  'T2M_MIN_5',
#  'T2M_5',
#  'QV2M_5',
#  'RH2M_5',
#  'PRECTOTCORR_5',
#  'PS_5',
#  'WS2M_5',
#  'WS2M_MAX_5',
#  'WS2M_MIN_5',
#  'WS2M_RANGE_5',
#  'WS10M_5',
#  'WS10M_MAX_5',
#  'WS10M_MIN_5',
#  'WS10M_RANGE_5',
#  'WS50M_5',
#  'WS50M_MAX_5',
#  'WS50M_MIN_5',
#  'WS50M_RANGE_5',
#  'GWETTOP_5',
#  'GWETROOT_5',
#  'GWETPROF_5',
#  'ALLSKY_SFC_SW_DWN_5',
#  'CLRSKY_SFC_SW_DWN_5',
#  'TOA_SW_DWN_5',
#  'ALLSKY_SFC_PAR_TOT_5',
#  'CLRSKY_SFC_PAR_TOT_5',
#  'ALLSKY_SFC_UVA_5',
#  'ALLSKY_SFC_UVB_5',
#  'ALLSKY_SFC_UV_INDEX_5',
#  'month_5',
#  'T2M_RANGE_6',
#  'TS_6',
#  'T2MDEW_6',
#  'T2MWET_6',
#  'T2M_MAX_6',
#  'T2M_MIN_6',
#  'T2M_6',
#  'QV2M_6',
#  'RH2M_6',
#  'PRECTOTCORR_6',
#  'PS_6',
#  'WS2M_6',
#  'WS2M_MAX_6',
#  'WS2M_MIN_6',
#  'WS2M_RANGE_6',
#  'WS10M_6',
#  'WS10M_MAX_6',
#  'WS10M_MIN_6',
#  'WS10M_RANGE_6',
#  'WS50M_6',
#  'WS50M_MAX_6',
#  'WS50M_MIN_6',
#  'WS50M_RANGE_6',
#  'GWETTOP_6',
#  'GWETROOT_6',
#  'GWETPROF_6',
#  'ALLSKY_SFC_SW_DWN_6',
#  'CLRSKY_SFC_SW_DWN_6',
#  'TOA_SW_DWN_6',
#  'ALLSKY_SFC_PAR_TOT_6',
#  'CLRSKY_SFC_PAR_TOT_6',
#  'ALLSKY_SFC_UVA_6',
#  'ALLSKY_SFC_UVB_6',
#  'ALLSKY_SFC_UV_INDEX_6',
#  'month_6',
#  'T2M_RANGE_7',
#  'TS_7',
#  'T2MDEW_7',
#  'T2MWET_7',
#  'T2M_MAX_7',
#  'T2M_MIN_7',
#  'T2M_7',
#  'QV2M_7',
#  'RH2M_7',
#  'PRECTOTCORR_7',
#  'PS_7',
#  'WS2M_7',
#  'WS2M_MAX_7',
#  'WS2M_MIN_7',
#  'WS2M_RANGE_7',
#  'WS10M_7',
#  'WS10M_MAX_7',
#  'WS10M_MIN_7',
#  'WS10M_RANGE_7',
#  'WS50M_7',
#  'WS50M_MAX_7',
#  'WS50M_MIN_7',
#  'WS50M_RANGE_7',
#  'GWETTOP_7',
#  'GWETROOT_7',
#  'GWETPROF_7',
#  'ALLSKY_SFC_SW_DWN_7',
#  'CLRSKY_SFC_SW_DWN_7',
#  'TOA_SW_DWN_7',
#  'ALLSKY_SFC_PAR_TOT_7',
#  'CLRSKY_SFC_PAR_TOT_7',
#  'ALLSKY_SFC_UVA_7',
#  'ALLSKY_SFC_UVB_7',
#  'ALLSKY_SFC_UV_INDEX_7',
#  'month_7',
#  'T2M_RANGE_8',
#  'TS_8',
#  'T2MDEW_8',
#  'T2MWET_8',
#  'T2M_MAX_8',
#  'T2M_MIN_8',
#  'T2M_8',
#  'QV2M_8',
#  'RH2M_8',
#  'PRECTOTCORR_8',
#  'PS_8',
#  'WS2M_8',
#  'WS2M_MAX_8',
#  'WS2M_MIN_8',
#  'WS2M_RANGE_8',
#  'WS10M_8',
#  'WS10M_MAX_8',
#  'WS10M_MIN_8',
#  'WS10M_RANGE_8',
#  'WS50M_8',
#  'WS50M_MAX_8',
#  'WS50M_MIN_8',
#  'WS50M_RANGE_8',
#  'GWETTOP_8',
#  'GWETROOT_8',
#  'GWETPROF_8',
#  'ALLSKY_SFC_SW_DWN_8',
#  'CLRSKY_SFC_SW_DWN_8',
#  'TOA_SW_DWN_8',
#  'ALLSKY_SFC_PAR_TOT_8',
#  'CLRSKY_SFC_PAR_TOT_8',
#  'ALLSKY_SFC_UVA_8',
#  'ALLSKY_SFC_UVB_8',
#  'ALLSKY_SFC_UV_INDEX_8',
#  'month_8',
#  'T2M_RANGE_9',
#  'TS_9',
#  'T2MDEW_9',
#  'T2MWET_9',
#  'T2M_MAX_9',
#  'T2M_MIN_9',
#  'T2M_9',
#  'QV2M_9',
#  'RH2M_9',
#  'PRECTOTCORR_9',
#  'PS_9',
#  'WS2M_9',
#  'WS2M_MAX_9',
#  'WS2M_MIN_9',
#  'WS2M_RANGE_9',
#  'WS10M_9',
#  'WS10M_MAX_9',
#  'WS10M_MIN_9',
#  'WS10M_RANGE_9',
#  'WS50M_9',
#  'WS50M_MAX_9',
#  'WS50M_MIN_9',
#  'WS50M_RANGE_9',
#  'GWETTOP_9',
#  'GWETROOT_9',
#  'GWETPROF_9',
#  'ALLSKY_SFC_SW_DWN_9',
#  'CLRSKY_SFC_SW_DWN_9',
#  'TOA_SW_DWN_9',
#  'ALLSKY_SFC_PAR_TOT_9',
#  'CLRSKY_SFC_PAR_TOT_9',
#  'ALLSKY_SFC_UVA_9',
#  'ALLSKY_SFC_UVB_9',
#  'ALLSKY_SFC_UV_INDEX_9',
#  'month_9',
#  'T2M_RANGE_10',
#  'TS_10',
#  'T2MDEW_10',
#  'T2MWET_10',
#  'T2M_MAX_10',
#  'T2M_MIN_10',
#  'T2M_10',
#  'QV2M_10',
#  'RH2M_10',
#  'PRECTOTCORR_10',
#  'PS_10',
#  'WS2M_10',
#  'WS2M_MAX_10',
#  'WS2M_MIN_10',
#  'WS2M_RANGE_10',
#  'WS10M_10',
#  'WS10M_MAX_10',
#  'WS10M_MIN_10',
#  'WS10M_RANGE_10',
#  'WS50M_10',
#  'WS50M_MAX_10',
#  'WS50M_MIN_10',
#  'WS50M_RANGE_10',
#  'GWETTOP_10',
#  'GWETROOT_10',
#  'GWETPROF_10',
#  'ALLSKY_SFC_SW_DWN_10',
#  'CLRSKY_SFC_SW_DWN_10',
#  'TOA_SW_DWN_10',
#  'ALLSKY_SFC_PAR_TOT_10',
#  'CLRSKY_SFC_PAR_TOT_10',
#  'ALLSKY_SFC_UVA_10',
#  'ALLSKY_SFC_UVB_10',
#  'ALLSKY_SFC_UV_INDEX_10',
#  'month_10',
#  'T2M_RANGE_11',
#  'TS_11',
#  'T2MDEW_11',
#  'T2MWET_11',
#  'T2M_MAX_11',
#  'T2M_MIN_11',
#  'T2M_11',
#  'QV2M_11',
#  'RH2M_11',
#  'PRECTOTCORR_11',
#  'PS_11',
#  'WS2M_11',
#  'WS2M_MAX_11',
#  'WS2M_MIN_11',
#  'WS2M_RANGE_11',
#  'WS10M_11',
#  'WS10M_MAX_11',
#  'WS10M_MIN_11',
#  'WS10M_RANGE_11',
#  'WS50M_11',
#  'WS50M_MAX_11',
#  'WS50M_MIN_11',
#  'WS50M_RANGE_11',
#  'GWETTOP_11',
#  'GWETROOT_11',
#  'GWETPROF_11',
#  'ALLSKY_SFC_SW_DWN_11',
#  'CLRSKY_SFC_SW_DWN_11',
#  'TOA_SW_DWN_11',
#  'ALLSKY_SFC_PAR_TOT_11',
#  'CLRSKY_SFC_PAR_TOT_11',
#  'ALLSKY_SFC_UVA_11',
#  'ALLSKY_SFC_UVB_11',
#  'ALLSKY_SFC_UV_INDEX_11',
#  'month_11',
#  'T2M_RANGE_12',
#  'TS_12',
#  'T2MDEW_12',
#  'T2MWET_12',
#  'T2M_MAX_12',
#  'T2M_MIN_12',
#  'T2M_12',
#  'QV2M_12',
#  'RH2M_12',
#  'PRECTOTCORR_12',
#  'PS_12',
#  'WS2M_12',
#  'WS2M_MAX_12',
#  'WS2M_MIN_12',
#  'WS2M_RANGE_12',
#  'WS10M_12',
#  'WS10M_MAX_12',
#  'WS10M_MIN_12',
#  'WS10M_RANGE_12',
#  'WS50M_12',
#  'WS50M_MAX_12',
#  'WS50M_MIN_12',
#  'WS50M_RANGE_12',
#  'GWETTOP_12',
#  'GWETROOT_12',
#  'GWETPROF_12',
#  'ALLSKY_SFC_SW_DWN_12',
#  'CLRSKY_SFC_SW_DWN_12',
#  'TOA_SW_DWN_12',
#  'ALLSKY_SFC_PAR_TOT_12',
#  'CLRSKY_SFC_PAR_TOT_12',
#  'ALLSKY_SFC_UVA_12',
#  'ALLSKY_SFC_UVB_12',
#  'ALLSKY_SFC_UV_INDEX_12',
#  'month_12',
#  'month',
#  'year']

# %% [markdown]
# #### Iremos criar um dataset menor para cada mês, mudar o nome dos indices para o indice_mes e depois juntar todos em um dataset com todos os indices ordenados por mês.

# %%
df_m=datanew[col].loc[datanew['month']==1].rename(columns=dict(zip(col[0:34],lista_indices[1:35]))).drop(columns='month')

a=35
b=69
for i in range(11):
        
    df_m2=datanew[col].loc[datanew['month']==i+2].rename(columns=dict(zip(col[0:34],lista_indices[a:b]))).drop(columns='month')
    a=b
    b=b+34
    df_m=pd.concat([df_m.reset_index(drop=True),df_m2.reset_index(drop=True)], axis=1)

# %% [markdown]
# Utilizando apenas os meses de plantio e colheita:

# %%
df_m
# Out:
#      T2M_RANGE_1       TS_1   T2MDEW_1   T2MWET_1  T2M_MAX_1  T2M_MIN_1  \
# 0      12.313226  27.513548  19.130968  22.804839  32.921290  20.608387
# 1       8.789677  26.006774  21.852903  23.737419  30.293226  21.501613
# 2      11.466774  28.138710  20.220000  23.727419  33.260645  21.793871
# 3       7.730000  25.683871  22.430323  23.973226  29.698710  21.968710
# 4      10.218710  26.340323  20.238710  22.941290  31.066452  20.848710
# ..           ...        ...        ...        ...        ...        ...
# 335     8.425484  23.434516  20.681290  22.045806  27.865161  19.438710
# 336     8.140968  23.840000  20.865484  22.313226  28.296452  20.155161
# 337     7.663871  22.996129  20.359355  21.692258  27.200645  19.538387
# 338     9.545484  25.754839  21.086774  23.382581  30.743226  21.199677
# 339    11.594839  25.560000  19.407419  22.238065  31.291935  19.697419
#
#          T2M_1     QV2M_1     RH2M_1  PRECTOTCORR_1  ...  WS2M_MIN_12  \
# 0    26.477097  14.547742  67.569032       2.531935  ...     0.652581
# 1    25.623871  17.136774  81.254516       7.784839  ...     0.610000
# 2    27.234516  15.484839  69.205484       4.431613  ...     0.680000
# 3    25.514194  17.737419  84.159032       8.712581  ...     0.607097
# 4    25.641935  15.544194  74.416774       3.609032  ...     0.566774
# ..         ...        ...        ...            ...  ...          ...
# 335  23.411290  16.423226  85.927097       9.002258  ...     0.738065
# 336  23.761935  16.457742  85.124194       7.655806  ...     0.736129
# 337  23.025806  15.981613  86.016452       7.799032  ...     0.667419
# 338  25.675161  16.675484  78.064194       4.329032  ...     0.770000
# 339  25.067742  15.197419  74.130968       3.652581  ...     0.718710
#
#      WS2M_RANGE_12   WS10M_12  WS10M_MAX_12  WS10M_MIN_12  WS10M_RANGE_12  \
# 0         0.662258  23.674839     30.573548     42.462258      128.402581
# 1         0.614516  23.596129     30.226129     42.446129      128.496452
# 2         0.675161  21.499032     29.592903     42.435806      117.794194
# 3         0.613226  23.464194     30.246774     42.436129      127.693871
# 4         0.573226  25.211290     30.488065     42.445484      136.012581
# ..             ...        ...           ...           ...             ...
# 335       0.729677  21.962903     30.644194     42.817742      119.750645
# 336       0.728387  21.611290     30.383548     42.809032      118.041935
# 337       0.667097  25.597419     31.188065     42.804516      138.342258
# 338       0.757419  22.388387     31.019032     42.801935      121.082258
# 339       0.710323  21.933226     31.043226     42.821935      119.596129
#
#        WS50M_12  WS50M_MAX_12  WS50M_MIN_12  WS50M_RANGE_12
# 0    162.105161     17.306452      0.508065      -29.687742
# 1    160.859677     17.292581      0.511613        2.659677
# 2    157.387097     15.792258      0.492258        2.596129
# 3    160.882258     17.193548      0.508065        2.643548
# 4    161.500968     18.207742      0.551935      -61.747742
# ..          ...           ...           ...             ...
# 335  163.210645     16.173871      0.500000        2.630323
# 336  162.134516     15.931935      0.481290      -29.819677
# 337  165.951290     18.576452      0.563548        2.961290
# 338  164.555161     16.335484      0.492581        2.577742
# 339  165.493871     16.101290      0.497097        2.626129
#
# [340 rows x 408 columns]

# %% [markdown]
# #### Reinserindo ano e codigo do ibge:

# %%
df_m['codigo_ibge']=datanew['codigo_ibge'].loc[datanew['month']==1].reset_index(drop=True)
df_m['year']=datanew['year'].loc[datanew['month']==1].reset_index(drop=True)

# %%
df_m.head()
# Out:
#    T2M_RANGE_1       TS_1   T2MDEW_1   T2MWET_1  T2M_MAX_1  T2M_MIN_1  \
# 0    12.313226  27.513548  19.130968  22.804839  32.921290  20.608387
# 1     8.789677  26.006774  21.852903  23.737419  30.293226  21.501613
# 2    11.466774  28.138710  20.220000  23.727419  33.260645  21.793871
# 3     7.730000  25.683871  22.430323  23.973226  29.698710  21.968710
# 4    10.218710  26.340323  20.238710  22.941290  31.066452  20.848710
#
#        T2M_1     QV2M_1     RH2M_1  PRECTOTCORR_1  ...   WS10M_12  \
# 0  26.477097  14.547742  67.569032       2.531935  ...  23.674839
# 1  25.623871  17.136774  81.254516       7.784839  ...  23.596129
# 2  27.234516  15.484839  69.205484       4.431613  ...  21.499032
# 3  25.514194  17.737419  84.159032       8.712581  ...  23.464194
# 4  25.641935  15.544194  74.416774       3.609032  ...  25.211290
#
#    WS10M_MAX_12  WS10M_MIN_12  WS10M_RANGE_12    WS50M_12  WS50M_MAX_12  \
# 0     30.573548     42.462258      128.402581  162.105161     17.306452
# 1     30.226129     42.446129      128.496452  160.859677     17.292581
# 2     29.592903     42.435806      117.794194  157.387097     15.792258
# 3     30.246774     42.436129      127.693871  160.882258     17.193548
# 4     30.488065     42.445484      136.012581  161.500968     18.207742
#
#    WS50M_MIN_12  WS50M_RANGE_12  codigo_ibge  year
# 0      0.508065      -29.687742      4128005  2004
# 1      0.511613        2.659677      4128005  2005
# 2      0.492258        2.596129      4128005  2006
# 3      0.508065        2.643548      4128005  2007
# 4      0.551935      -61.747742      4128005  2008
#
# [5 rows x 410 columns]

# %%
X_train=df_m.loc[df_m['year']<2018]
X_test=df_m.loc[df_m['year']>2017]

# %% [markdown]
# #### Scalando os dados:

# %%
colunas_=list(X_train.keys())

colunas_.remove('year')
colunas_.remove('codigo_ibge')
#removendo os dados que não serão escalados

# %%
len(colunas_)
# Out:
# 408

# %%
X_train
# Out:
#      T2M_RANGE_1       TS_1   T2MDEW_1   T2MWET_1  T2M_MAX_1  T2M_MIN_1  \
# 0      12.313226  27.513548  19.130968  22.804839  32.921290  20.608387
# 1       8.789677  26.006774  21.852903  23.737419  30.293226  21.501613
# 2      11.466774  28.138710  20.220000  23.727419  33.260645  21.793871
# 3       7.730000  25.683871  22.430323  23.973226  29.698710  21.968710
# 4      10.218710  26.340323  20.238710  22.941290  31.066452  20.848710
# ..           ...        ...        ...        ...        ...        ...
# 332    10.849355  23.446129  18.836774  21.040000  28.912258  18.062581
# 333     9.336129  24.036774  20.015484  22.099677  28.984194  19.649032
# 334     9.156774  24.720968  20.784194  22.766129  29.548065  20.391613
# 335     8.425484  23.434516  20.681290  22.045806  27.865161  19.438710
# 336     8.140968  23.840000  20.865484  22.313226  28.296452  20.155161
#
#          T2M_1     QV2M_1     RH2M_1  PRECTOTCORR_1  ...   WS10M_12  \
# 0    26.477097  14.547742  67.569032       2.531935  ...  23.674839
# 1    25.623871  17.136774  81.254516       7.784839  ...  23.596129
# 2    27.234516  15.484839  69.205484       4.431613  ...  21.499032
# 3    25.514194  17.737419  84.159032       8.712581  ...  23.464194
# 4    25.641935  15.544194  74.416774       3.609032  ...  25.211290
# ..         ...        ...        ...            ...  ...        ...
# 332  23.244839  14.600645  78.423548       4.669677  ...  24.709355
# 333  24.183226  15.638387  79.412581       6.101613  ...  21.390645
# 334  24.748710  16.382258  80.409355       4.708387  ...  16.696774
# 335  23.411290  16.423226  85.927097       9.002258  ...  21.962903
# 336  23.761935  16.457742  85.124194       7.655806  ...  21.611290
#
#      WS10M_MAX_12  WS10M_MIN_12  WS10M_RANGE_12    WS50M_12  WS50M_MAX_12  \
# 0       30.573548     42.462258      128.402581  162.105161     17.306452
# 1       30.226129     42.446129      128.496452  160.859677     17.292581
# 2       29.592903     42.435806      117.794194  157.387097     15.792258
# 3       30.246774     42.436129      127.693871  160.882258     17.193548
# 4       30.488065     42.445484      136.012581  161.500968     18.207742
# ..            ...           ...             ...         ...           ...
# 332     30.882581     42.822581      134.274194  165.051613     18.018065
# 333     30.376452     42.826452      116.979032  162.129032     15.787742
# 334     29.344516     42.818065       92.785806  157.218387     12.595806
# 335     30.644194     42.817742      119.750645  163.210645     16.173871
# 336     30.383548     42.809032      118.041935  162.134516     15.931935
#
#      WS50M_MIN_12  WS50M_RANGE_12  codigo_ibge  year
# 0        0.508065      -29.687742      4128005  2004
# 1        0.511613        2.659677      4128005  2005
# 2        0.492258        2.596129      4128005  2006
# 3        0.508065        2.643548      4128005  2007
# 4        0.551935      -61.747742      4128005  2008
# ..            ...             ...          ...   ...
# 332      0.545806        2.874839      4102000  2013
# 333      0.468065        2.419032      4102000  2014
# 334      0.382258        1.980968      4102000  2015
# 335      0.500000        2.630323      4102000  2016
# 336      0.481290      -29.819677      4102000  2017
#
# [280 rows x 410 columns]

# %% [markdown]
# ### Podemos criar um pipeline com as etapas do processo para testes:

# %%
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline

from sklearn.tree import DecisionTreeRegressor # Decision Tree Regression

# %%
pipe= Pipeline([('scaler', StandardScaler()),
               ('clf', SVC(kernel='rbf',gamma='auto', C=1.0))]) #,RandomForestRegressor(n_estimators=100, random_state=0))])#

#pipe.fit(X_train,Y_train)

# %%
df_out=pd.DataFrame(columns=['codigo_ibge','2018','2019','2020'])

for i in codigo_saida:
    
    X_train_menor=X_train.loc[X_train['codigo_ibge']==i].drop(columns=['codigo_ibge'])
    Y_train_menor=Y_train[Y_train['codigo_ibge']==i].drop(columns='codigo_ibge').T
    
    pipe.fit(X_train_menor, Y_train_menor.values.ravel())
    
    
    X_test_menor=X_test.loc[X_test['codigo_ibge']==i].drop(columns=['codigo_ibge'])
    
    
    #pipe.fit_predict()
    predicoes=pipe.predict(X_test_menor)

    data_saida={'codigo_ibge':i, '2018':predicoes[0], '2019':predicoes[1], '2020':predicoes[2]}
    
    data_saida=pd.DataFrame([data_saida])
    
    
    
    df_out=pd.concat([df_out,data_saida])

# %%
df_out=df_out.reset_index(drop=True)

# %%
df_out
# Out:
#    codigo_ibge    2018    2019    2020
# 0      4102000  3493.0  2968.0  2064.0
# 1      4104303  3293.0  2677.0  2496.0
# 2      4104428  3380.0  2852.0  2500.0
# 3      4104808  3655.0  3655.0  3655.0
# 4      4104907  3690.0  3542.0  4000.0
# 5      4109401  2849.0  4120.0  3529.0
# 6      4113205  3350.0  3350.0  3000.0
# 7      4113700  2880.0  2880.0  2880.0
# 8      4113734  3211.0  3471.0  2963.0
# 9      4114005  3148.0  3350.0  2592.0
# 10     4114401  2713.0  3278.0  3278.0
# 11     4117701  2700.0  3200.0  2850.0
# 12     4117909  3166.0  2957.0  1956.0
# 13     4119608  2837.0  2800.0  3000.0
# 14     4119905  3698.0  3199.0  3496.0
# 15     4127007  3268.0  3268.0  3268.0
# 16     4127403  2943.0  2984.0  2943.0
# 17     4127502  3050.0  3000.0  3050.0
# 18     4127700  3164.0  3475.0  3164.0
# 19     4128005  3150.0  3343.0  3150.0

# %%
df_out.to_csv('submission.csv',index=False)
